# %% [markdown]
# # Lesson 3 - Excercises

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

insect_data = pd.read_csv("data/InformationGainData.csv")

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.plot(insect_data["Color"],insect_data["Length (mm)"], label='Data Points')

plt.xlabel('Color')
plt.ylabel('Length')
plt.legend()

plt.show()
